# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = "resources/2019data.csv"
data2020 = "resources/NYPD_Arrest_Data__Year_to_Date_.csv"
nypd_data = pd.read_csv(data, parse_dates=["ARREST_DATE"])
nypd_data2020 = pd.read_csv(data2020, parse_dates=["ARREST_DATE"])

# %%
may_data_19 = nypd_data.loc[(nypd_data["ARREST_DATE"] > "05/01/2019") & (nypd_data["ARREST_DATE"] < "06/01/2019"), :]
may_data_19.head()
# Out:
#       ARREST_DATE  PD_CD                  PD_DESC  \
# 76906  2019-05-02  101.0                ASSAULT 3
# 76907  2019-05-02  639.0  AGGRAVATED HARASSMENT 2
# 76908  2019-05-02  181.0  IMPRISONMENT 2,UNLAWFUL
# 76909  2019-05-02  569.0    MARIJUANA, SALE 4 & 5
# 76910  2019-05-02  744.0           BAIL JUMPING 3
#
#                             OFNS_DESC AGE_GROUP
# 76906    ASSAULT 3 & RELATED OFFENSES     25-44
# 76907   OFF. AGNST PUB ORD SENSBLTY &       <18
# 76908     OFFENSES AGAINST THE PERSON       <18
# 76909                 DANGEROUS DRUGS     18-24
# 76910  OFFENSES AGAINST PUBLIC ADMINI     25-44

# %%
group_ofns_19 = may_data_19.groupby("OFNS_DESC")
count_ofns_19 = group_ofns_19["OFNS_DESC"].count().sort_values(ascending=False).head(15)
count_ofns_19
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      2883
# PETIT LARCENY                     1946
# DANGEROUS DRUGS                   1773
# FELONY ASSAULT                    1379
# VEHICLE AND TRAFFIC LAWS          1286
# MISCELLANEOUS PENAL LAW           1101
# CRIMINAL MISCHIEF & RELATED OF     868
# ROBBERY                            798
# DANGEROUS WEAPONS                  781
# GRAND LARCENY                      777
# OFFENSES AGAINST PUBLIC ADMINI     680
# INTOXICATED & IMPAIRED DRIVING     424
# SEX CRIMES                         399
# FORGERY                            364
# OFF. AGNST PUB ORD SENSBLTY &      356
# Name: OFNS_DESC, dtype: int64

# %%
plt.figure(figsize=(5,10))

ofns_chart_19 = count_ofns_19.sort_values().plot(kind="barh", alpha=0.5, fontsize=10)
plt.title("Top 15 Crimes May 2019", fontsize=10)
plt.ylabel("Offense Type", fontsize=10)
plt.xlabel("Count", fontsize=10)

plt.show()

# %%
may_data_20 = nypd_data2020.loc[(nypd_data2020["ARREST_DATE"] > "05/01/2020") & (nypd_data2020["ARREST_DATE"] < "06/01/2020"), :]
may_data_20.head()
# Out:
#     ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 5    213557081  2020-05-27  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 11   213153714  2020-05-16  503.0  CONTROLLED SUBSTANCE,INTENT TO  117.0
# 16   213672089  2020-05-29  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 18   212963813  2020-05-12  268.0              CRIMINAL MIS 2 & 3  121.0
# 20   212875789  2020-05-09  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
#
#                          OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 5                          ROBBERY  PL 1601503          F           Q
# 11                 DANGEROUS DRUGS  PL 2201601          F           M
# 16                   PETIT LARCENY  PL 1552500          M           S
# 18  CRIMINAL MISCHIEF & RELATED OF  PL 1451000          F           M
# 20                   PETIT LARCENY  PL 1552500          M           B
#
#     ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# ...

# %%
group_ofns_20 = may_data_20.groupby("OFNS_DESC")
count_ofns_20 = group_ofns_20["OFNS_DESC"].count().sort_values(ascending=False).head(15)
count_ofns_20
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      2127
# DANGEROUS DRUGS                   1299
# FELONY ASSAULT                    1168
# PETIT LARCENY                     1010
# MISCELLANEOUS PENAL LAW            861
# CRIMINAL MISCHIEF & RELATED OF     797
# BURGLARY                           708
# DANGEROUS WEAPONS                  698
# ROBBERY                            682
# OFFENSES AGAINST PUBLIC ADMINI     553
# GRAND LARCENY                      550
# VEHICLE AND TRAFFIC LAWS           343
# OFF. AGNST PUB ORD SENSBLTY &      343
# SEX CRIMES                         264
# CRIMINAL TRESPASS                  183
# Name: OFNS_DESC, dtype: int64

# %%
plt.figure(figsize=(5,10))

ofns_chart_20 = count_ofns_20.sort_values().plot(kind="barh", alpha=0.5, fontsize=10)
plt.title("Top 15 Crimes May 2020", fontsize=10)
plt.ylabel("Offense Type", fontsize=10)
plt.xlabel("Count", fontsize=10)

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

plt.subplot(1, 2, 1)

ofns_chart_20 = count_ofns_20.sort_values().plot(kind="barh", alpha=0.5, fontsize=10)
plt.title("Top 15 Crimes May 2020", fontsize=10)
plt.ylabel("Offense Type", fontsize=10)
plt.xlabel("Count", fontsize=10)

plt.subplot(1, 2, 2)
ofns_chart_19 = count_ofns_19.sort_values().plot(kind="barh", alpha=0.5, fontsize=10)
plt.title("Top 15 Crimes May 2019", fontsize=10)
plt.ylabel("Offense Type", fontsize=10)
plt.xlabel("Count", fontsize=10)

fig.tight_layout()
plt.show()

# %%
# use .loc
group_18_24 = may_data_19.loc[may_data_19["AGE_GROUP"] == "18-24"]

# use groupby
may_group_18 = group_18_24.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
may_group_18
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      565
# PETIT LARCENY                     329
# FELONY ASSAULT                    282
# DANGEROUS DRUGS                   280
# DANGEROUS WEAPONS                 239
# VEHICLE AND TRAFFIC LAWS          221
# MISCELLANEOUS PENAL LAW           219
# CRIMINAL MISCHIEF & RELATED OF    201
# GRAND LARCENY                     193
# ROBBERY                           191
# OFFENSES AGAINST PUBLIC ADMINI    181
# FORGERY                           115
# CRIMINAL TRESPASS                 109
# POSSESSION OF STOLEN PROPERTY      70
# OTHER OFFENSES RELATED TO THEF     67
# Name: ARREST_DATE, dtype: int64

# %%
# use .loc
group_25_44 = may_data_19.loc[may_data_19["AGE_GROUP"] == "25-44"]

# use groupby
may_group_25 = group_25_44.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
may_group_25
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      1577
# DANGEROUS DRUGS                    999
# PETIT LARCENY                      956
# VEHICLE AND TRAFFIC LAWS           767
# FELONY ASSAULT                     707
# MISCELLANEOUS PENAL LAW            621
# CRIMINAL MISCHIEF & RELATED OF     501
# DANGEROUS WEAPONS                  365
# OFFENSES AGAINST PUBLIC ADMINI     364
# GRAND LARCENY                      355
# ROBBERY                            287
# INTOXICATED & IMPAIRED DRIVING     264
# SEX CRIMES                         234
# OFF. AGNST PUB ORD SENSBLTY &      214
# OTHER OFFENSES RELATED TO THEF     186
# Name: ARREST_DATE, dtype: int64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

plt.subplot(1, 2, 1)

may_group_18.sort_values().plot(kind="bar", color="silver", alpha=0.75, fontsize=12)

plt.title("Age Group 18-24 vs. Crime (May 2019)", fontsize=12)
plt.ylabel("Number of Offenses", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)

plt.subplot(1, 2, 2)
may_group_25.sort_values().plot(kind="bar", color="silver", alpha=0.75, fontsize=12)
plt.title("Age Group 25-44 vs. Crime (May 2019)", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)
# Out:
# Text(0.5, 0, 'Offense Type')

# %%
# use .loc
group_18_24 = may_data_20.loc[may_data_20["AGE_GROUP"] == "18-24"]

# use groupby
may_group_18 = group_18_24.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
may_group_18
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      378
# DANGEROUS DRUGS                   224
# FELONY ASSAULT                    217
# DANGEROUS WEAPONS                 213
# ROBBERY                           196
# MISCELLANEOUS PENAL LAW           170
# OFFENSES AGAINST PUBLIC ADMINI    149
# CRIMINAL MISCHIEF & RELATED OF    145
# PETIT LARCENY                     120
# GRAND LARCENY                     119
# VEHICLE AND TRAFFIC LAWS           92
# OFF. AGNST PUB ORD SENSBLTY &      91
# BURGLARY                           77
# GRAND LARCENY OF MOTOR VEHICLE     63
# CRIMINAL TRESPASS                  52
# Name: ARREST_DATE, dtype: int64

# %%
# use .loc
group_25_44 = may_data_20.loc[may_data_20["AGE_GROUP"] == "25-44"]

# use groupby
may_group_25 = group_25_44.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
may_group_25
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      1256
# DANGEROUS DRUGS                    753
# FELONY ASSAULT                     657
# PETIT LARCENY                      556
# MISCELLANEOUS PENAL LAW            507
# CRIMINAL MISCHIEF & RELATED OF     479
# DANGEROUS WEAPONS                  357
# BURGLARY                           329
# OFFENSES AGAINST PUBLIC ADMINI     321
# ROBBERY                            293
# GRAND LARCENY                      274
# OFF. AGNST PUB ORD SENSBLTY &      204
# VEHICLE AND TRAFFIC LAWS           203
# SEX CRIMES                         157
# INTOXICATED & IMPAIRED DRIVING      94
# Name: ARREST_DATE, dtype: int64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

plt.subplot(1, 2, 1)

may_group_18.sort_values().plot(kind="bar", color="purple", alpha=0.5, fontsize=12)

plt.title("Age Group 18-24 vs. Crime (May 2020)", fontsize=12)
plt.ylabel("Number of Offenses", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)

plt.subplot(1, 2, 2)
may_group_25.sort_values().plot(kind="bar", color="purple", alpha=0.5, fontsize=12)
plt.title("Age Group 25-44 vs. Crime (May 2020)", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)
# Out:
# Text(0.5, 0, 'Offense Type')

# %%
data_19 = nypd_data.loc[(nypd_data["ARREST_DATE"] > "03/01/2019") & (nypd_data["ARREST_DATE"] < "06/01/2019"), :]
data_19.head()
# Out:
#       ARREST_DATE  PD_CD                         PD_DESC  \
# 37915  2019-03-02  201.0       TRESPASS 4,CRIMINAL SUB 2
# 37916  2019-03-02  478.0  THEFT OF SERVICES, UNCLASSIFIE
# 37917  2019-03-02  101.0                       ASSAULT 3
# 37918  2019-03-02  729.0  FORGERY,ETC.,UNCLASSIFIED-FELO
# 37919  2019-03-02  566.0           MARIJUANA, POSSESSION
#
#                             OFNS_DESC AGE_GROUP
# 37915         MISCELLANEOUS PENAL LAW     45-64
# 37916  OTHER OFFENSES RELATED TO THEF     25-44
# 37917    ASSAULT 3 & RELATED OFFENSES     18-24
# 37918                         FORGERY     25-44
# 37919         MISCELLANEOUS PENAL LAW     25-44

# %%
group_18_24 = data_19.loc[data_19["AGE_GROUP"] == "18-24"]

# use groupby
age_group_18 = group_18_24.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
age_group_18
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      1690
# DANGEROUS DRUGS                    917
# PETIT LARCENY                      897
# FELONY ASSAULT                     818
# VEHICLE AND TRAFFIC LAWS           766
# DANGEROUS WEAPONS                  703
# MISCELLANEOUS PENAL LAW            663
# CRIMINAL MISCHIEF & RELATED OF     660
# GRAND LARCENY                      579
# ROBBERY                            564
# OFFENSES AGAINST PUBLIC ADMINI     510
# FORGERY                            356
# OTHER OFFENSES RELATED TO THEF     327
# CRIMINAL TRESPASS                  317
# OFF. AGNST PUB ORD SENSBLTY &      226
# Name: ARREST_DATE, dtype: int64

# %%
group_25_44 = data_19.loc[data_19["AGE_GROUP"] == "25-44"]

# use groupby
age_group_25 = group_25_44.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
age_group_25
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      4521
# DANGEROUS DRUGS                   3257
# PETIT LARCENY                     2664
# VEHICLE AND TRAFFIC LAWS          2530
# FELONY ASSAULT                    2143
# MISCELLANEOUS PENAL LAW           1890
# CRIMINAL MISCHIEF & RELATED OF    1522
# GRAND LARCENY                     1254
# DANGEROUS WEAPONS                 1102
# OFFENSES AGAINST PUBLIC ADMINI    1101
# ROBBERY                            850
# INTOXICATED & IMPAIRED DRIVING     850
# FORGERY                            765
# OFF. AGNST PUB ORD SENSBLTY &      695
# SEX CRIMES                         666
# Name: ARREST_DATE, dtype: int64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

plt.subplot(1, 2, 1)

age_group_18.plot(kind="bar", color="purple", alpha=0.6, fontsize=12)

plt.title("Age Group 18-24 vs. Crime (2019)", fontsize=12)
plt.ylabel("Number of Offenses", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)

plt.subplot(1, 2, 2)
age_group_25.plot(kind="bar", color="purple", alpha=0.6, fontsize=12)
plt.title("Age Group 25-44 vs. Crime (2019)", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)
# Out:
# Text(0.5, 0, 'Offense Type')

# %%
data_20 = nypd_data2020.loc[(nypd_data2020["ARREST_DATE"] > "03/01/2020") & (nypd_data2020["ARREST_DATE"] < "06/01/2020"), :]
data_20.head()
# Out:
#     ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 1    210517846  2020-03-04  969.0  TRAFFIC,UNCLASSIFIED INFRACTIO  881.0
# 5    213557081  2020-05-27  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 7    210784443  2020-03-10  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 11   213153714  2020-05-16  503.0  CONTROLLED SUBSTANCE,INTENT TO  117.0
# 12   210749767  2020-03-09  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
#
#                    OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 1   OTHER TRAFFIC INFRACTION  VTL051101A          M           M
# 5                    ROBBERY  PL 1601503          F           Q
# 7              PETIT LARCENY  PL 1552500          M           M
# 11           DANGEROUS DRUGS  PL 2201601          F           M
# 12  VEHICLE AND TRAFFIC LAWS  VTL1220B01          M           Q
#
#     ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# ...

# %%
younger_group_18_24 = data_20.loc[data_20["AGE_GROUP"] == "18-24"]

# use groupby
younger_age_group_18 = group_18_24.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
younger_age_group_18
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      1060
# FELONY ASSAULT                     625
# ROBBERY                            545
# DANGEROUS WEAPONS                  520
# DANGEROUS DRUGS                    516
# CRIMINAL MISCHIEF & RELATED OF     428
# MISCELLANEOUS PENAL LAW            421
# OFFENSES AGAINST PUBLIC ADMINI     374
# PETIT LARCENY                      362
# GRAND LARCENY                      357
# VEHICLE AND TRAFFIC LAWS           237
# BURGLARY                           215
# OFF. AGNST PUB ORD SENSBLTY &      158
# CRIMINAL TRESPASS                  134
# GRAND LARCENY OF MOTOR VEHICLE     133
# Name: ARREST_DATE, dtype: int64

# %%
older_group_25_44 = data_20.loc[data_20["AGE_GROUP"] == "25-44"]

# use groupby
older_age_group_25 = group_25_44.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
older_age_group_25
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      3355
# FELONY ASSAULT                    1762
# PETIT LARCENY                     1684
# DANGEROUS DRUGS                   1682
# MISCELLANEOUS PENAL LAW           1377
# CRIMINAL MISCHIEF & RELATED OF    1212
# DANGEROUS WEAPONS                  814
# BURGLARY                           801
# OFFENSES AGAINST PUBLIC ADMINI     784
# GRAND LARCENY                      784
# ROBBERY                            765
# VEHICLE AND TRAFFIC LAWS           641
# OFF. AGNST PUB ORD SENSBLTY &      411
# SEX CRIMES                         391
# INTOXICATED & IMPAIRED DRIVING     288
# Name: ARREST_DATE, dtype: int64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

plt.subplot(1, 2, 1)

younger_age_group_18.plot(kind="bar", color="green", alpha=0.6, fontsize=12)

plt.title("Age Group 18-24 vs. Crime (2020)", fontsize=12)
plt.ylabel("Number of Offenses", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)

plt.subplot(1, 2, 2)
older_age_group_25.plot(kind="bar", color="green", alpha=0.6, fontsize=12)
plt.title("Age Group 25-44 vs. Crime (2020)", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)
# Out:
# Text(0.5, 0, 'Offense Type')
